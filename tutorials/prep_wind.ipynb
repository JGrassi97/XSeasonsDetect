# %%
import xarray as xr
from preprocessing import netcdf_preprocess_CDO as prep
import geopandas as gpd

# %%
boundary = gpd.read_file('/home/jgrassi/work/XSeasonsDetect/INDIA/data/raw/shapefiles/boundary.gpkg')

# %%
dat = xr.open_mfdataset('/home/jgrassi/work/ERA5_data/v_wind_850/clipped/v_wind_850_*.nc').isel(pressure_level=0)
dat = dat.rename({'valid_time':'time'}).chunk(dict(time=-1))

dat
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 22646, lon: 41, lat: 36)
# Coordinates:
#   * time            (time) datetime64[ns] 1960-01-01 1960-01-02 ... 2021-12-31
#   * lon             (lon) float64 65.0 66.0 67.0 68.0 ... 103.0 104.0 105.0
#   * lat             (lat) float64 5.0 6.0 7.0 8.0 9.0 ... 37.0 38.0 39.0 40.0
#     pressure_level  float64 850.0
# Data variables:
#     v               (time, lat, lon) float32 dask.array<chunksize=(22646, 36, 41), meta=np.ndarray>
# Attributes:
#     CDI:                     Climate Data Interface version 2.0.4 (https://mp...
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     history:                 Mon Jan 13 10:29:46 2025: cdo remapbil,/home/jgr...
#     CDO:                     Climate Data Operators version 2.0.4 (https://mp...

# %%
dat = prep.sel_years(dat, str(1961),str(2019))
dat = prep.interpolate_na(dat)
dat = prep.clean_cut(dat, boundary, 15, True)

dat = dat.drop(['spatial_ref', 'pressure_level'])
dat
# Out:
# /tmp/ipykernel_1811549/2250696091.py:5: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   dat = dat.drop(['spatial_ref', 'pressure_level'])
# <xarray.Dataset>
# Dimensions:  (time: 20805, lon: 36, lat: 36)
# Coordinates:
#   * time     (time) object 1962-01-01 00:00:00 ... 2018-12-31 00:00:00
#   * lon      (lon) float64 65.0 66.0 67.0 68.0 69.0 ... 97.0 98.0 99.0 100.0
#   * lat      (lat) float64 5.0 6.0 7.0 8.0 9.0 10.0 ... 36.0 37.0 38.0 39.0 40.0
# Data variables:
#     v        (time, lat, lon) float32 dask.array<chunksize=(20805, 36, 36), meta=np.ndarray>
# Attributes:
#     CDI:                     Climate Data Interface version 2.0.4 (https://mp...
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# ...

# %%
dat.to_netcdf('/home/jgrassi/work/XSeasonsDetect/INDIA/data/preprocessed/ERA5/v850/final.nc')

# %%
xr.open_dataset('/home/jgrassi/work/XSeasonsDetect/INDIA/data/preprocessed/ERA5/total_precipitation/final.nc')
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 20805, lon: 36, lat: 36)
# Coordinates:
#   * time         (time) object 1962-01-01 11:30:00 ... 2018-12-31 11:30:00
#   * lon          (lon) float64 65.0 66.0 67.0 68.0 69.0 ... 97.0 98.0 99.0 100.0
#   * lat          (lat) float64 5.0 6.0 7.0 8.0 9.0 ... 36.0 37.0 38.0 39.0 40.0
#     spatial_ref  int64 ...
# Data variables:
#     tp           (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Mon Jan 13 14:19:01 2025: cdo remapbil,config/target_grid.t...
#     frequency:    day
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...
